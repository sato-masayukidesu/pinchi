# %%
import sys
sys.path.append("../../module")
from nxrd.Compound import Compound
from classes import MCS_Finder
import kcf.converter as kcfco
from rdkit.Chem import rdFMCS
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import rdDepictor

# %%
triplet = []
with open("Streptomyces/kcfscount.txt", "r")as f:
    lines = f.read().split("\n")
    for line in lines:
        if line == "":
            continue
        if line.split("\t")[1] == "TRIPLET":
            triplet.append(line)

# %%
print(triplet)
# Out:
# ['S00000001T\tTRIPLET\tC-C-C\t53255', 'S00000004T\tTRIPLET\tC-C-O\t31175', 'S00000008T\tTRIPLET\tC1-C1-C1\t19402', 'S00000010T\tTRIPLET\tC8-C8-C8\t11007', 'S00000012T\tTRIPLET\tC-C-N\t10925', 'S00000016T\tTRIPLET\tC1-C1-O2\t8580', 'S00000019T\tTRIPLET\tC1-C1-O1\t7144', 'S00000027T\tTRIPLET\tC-N-C\t5002', 'S00000028T\tTRIPLET\tC-O-C\t4479', 'S00000043T\tTRIPLET\tC1-C2-C2\t3444', 'S00000045T\tTRIPLET\tC1-C1-N1\t3302', 'S00000047T\tTRIPLET\tC8y-C8y-C8y\t3292', 'S00000050T\tTRIPLET\tC8x-C8y-C8y\t2981', 'S00000051T\tTRIPLET\tC1y-C1y-O1a\t2955', 'S00000053T\tTRIPLET\tC1-O2-C1\t2861', 'S00000054T\tTRIPLET\tC1-C1-C2\t2805', 'S00000055T\tTRIPLET\tN-C-O\t2782', 'S00000056T\tTRIPLET\tO-C-O\t2743', 'S00000057T\tTRIPLET\tC5-C8-C8\t2729', 'S00000058T\tTRIPLET\tC1-C1-C5\t2632', 'S00000059T\tTRIPLET\tC1-C8-C8\t2570', 'S00000061T\tTRIPLET\tC1-C5-O5\t2505', 'S00000068T\tTRIPLET\tC1y-C1y-C1y\t2315', 'S00000070T\tTRIPLET\tN1-C5-O5\t2208', 'S00000073T\tTRIPLET\tC8x-C8x-C8y\t2179', 'S00000074T\tTRIPLET\tC8-C8-O1\t2154', 'S00000078T\tTRIPLET\tC1y-C1y-O2x\t2013', 'S00000081T\tTRIPLET\tC1-N1-C5\t1986', 'S00000084T\tTRIPLET\tC5x-C8y-C8y\t1870', 'S00000090T\tTRIPLET\tC2-C2-C2\t1683', 'S00000093T\tTRIPLET\tC1-C5-N1\t1576', 'S00000096T\tTRIPLET\tC1-C1-O7\t1526', 'S00000099T\tTRIPLET\tC1y-C1y-O2a\t1480', 'S00000102T\tTRIPLET\tC8-C5-O5\t1461', 'S00000103T\tTRIPLET\tC8y-C8y-O1a\t1441', 'S00000106T\tTRIPLET\tC1x-C1y-C1y\t1395', 'S00000107T\tTRIPLET\tC1b-C1b-C1b\t1349', 'S00000108T\tTRIPLET\tC1a-C1y-C1y\t1320', 'S00000111T\tTRIPLET\tN1b-C5a-O5a\t1243', 'S00000116T\tTRIPLET\tC1y-O2x-C1y\t1205', 'S00000118T\tTRIPLET\tC8y-C5x-O5x\t1151', 'S00000122T\tTRIPLET\tC1-N1-C1\t1093', 'S00000123T\tTRIPLET\tC5-C1-N1\t1079', 'S00000
tC1b-C8y-C8x\t442', 'S00000245T\tTRIPLET\tC8-N5-C8\t440', 'S00000246T\tTRIPLET\tC1a-C1y-C1x\t439', 'S00000247T\tTRIPLET\tC8-C8-N1\t437', 'S00000249T\tTRIPLET\tC1b-C1b-C1c\t429', 'S00000251T\tTRIPLET\tC1x-C1y-O1a\t427', 'S00000253T\tTRIPLET\tO6a-C7x-O7x\t425', 'S00000258T\tTRIPLET\tC5x-C8y-C8x\t420', 'S00000259T\tTRIPL ...

# %%
print(len(triplet))
# Out:
# 2608

# %%
d = {"1":0, "2":0, "3":0}
for triple in triplet:
    d[str(len(triple.split("\t")[2].split("-")[0]))] += 1
print(d)
# Out:
# {'2': 450, '3': 2099, '1': 59}

# %%
counter = 0
for triple in triplet:
    if len(triple.split("\t")[2].split("-")[0]) == 1:
        counter += 1
        print(triple)
# Out:
# S00000001T	TRIPLET	C-C-C	53255
# S00000004T	TRIPLET	C-C-O	31175
# S00000012T	TRIPLET	C-C-N	10925
# S00000027T	TRIPLET	C-N-C	5002
# S00000028T	TRIPLET	C-O-C	4479
# S00000055T	TRIPLET	N-C-O	2782
# S00000056T	TRIPLET	O-C-O	2743
# S00000205T	TRIPLET	C-C-S	567
# S00000233T	TRIPLET	N-C-N	469
# S00000296T	TRIPLET	O-P-O	347
# S00000306T	TRIPLET	C-C-X	324
# S00000374T	TRIPLET	C-S-C	246
# S00000496T	TRIPLET	C-N-O	164
# S00000548T	TRIPLET	C-N-N	142
# S00000561T	TRIPLET	O-S-O	136
# S00000586T	TRIPLET	N-C-S	131
# S00000772T	TRIPLET	C-O-P	90
# S00001058T	TRIPLET	C-P-O	57
# S00001059T	TRIPLET	C-S-O	57
# S00001375T	TRIPLET	O-Z-O	37
# S00001537T	TRIPLET	N-P-O	30
# S00001738T	TRIPLET	O-C-S	24
# S00001739T	TRIPLET	O-N-O	24
# S00001783T	TRIPLET	N-C-X	23
# S00001802T	TRIPLET	C-O-S	22
# S00001853T	TRIPLET	C-S-S	21
# S00001915T	TRIPLET	C-O-Z	20
# S00002101T	TRIPLET	C-C-P	17
# S00002125T	TRIPLET	N-N-O	17
# S00002463T	TRIPLET	N-S-O	13
# S00002693T	TRIPLET	S-C-S	11
# S00002805T	TRIPLET	C-O-N	10
# S00002986T	TRIPLET	N-Z-O	9
# S00003130T	TRIPLET	C-N-P	8
# S00003207T	TRIPLET	O-C-P	8
# S00003764T	TRIPLET	P-O-P	6
# S00004064T	TRIPLET	C-S-N	5
# S00004642T	TRIPLET	C-O-O	4
# S00004643T	TRIPLET	C-Z-O	4
# S00004756T	TRIPLET	N-N-N	4
# S00004777T	TRIPLET	O-P-S	4
# S00004778T	TRIPLET	O-S-S	4
# S00005439T	TRIPLET	C-N-S	3
# S00005440T	TRIPLET	C-N-Z	3
# S00005604T	TRIPLET	N-O-Z	3
# S00005605T	TRIPLET	N-Z-N	3
# S00005625T	TRIPLET	O-N-Z	3
# S00006986T	TRIPLET	C-P-C	2
# S00007179T	TRIPLET	N-O-P	2
# S00007207T	TRIPLET	P-N-P	2
# S00010859T	TRIPLET	C-C-Z	1
# S00010860T	TRIPLET	C-S-P	1
# S00010861T	TRIPLET	C-Z-C	1
# S00011232T	TRIPLET	N-N-P	1
# S00011312T	TRIPLET	P-N-S	1
# S00011315T	TRIPLET	S-P-S	1
# S00011321T	TRIPLET	X-C-X	1
# S00011322T	TRIPLET	X-C1-X	1
# S00011323T	TRIPLET	X-C1c-X	1

# %%
print(counter)
# Out:
# 59

# %%
f = MCS_Finder("Streptomyces")

# %%
Cnumber = f.get_Cnlist_from_label2("C-S-S")

# %%
print(Cnumber)
# Out:
# ['C00016499', 'C00016500', 'C00016934', 'C00017555', 'C00018484', 'C00018653', 'C00018695', 'C00018696', 'C00018766']

# %%
Cnlist = []
for i in range(1, 52):
    page = str(i)
    with open("../../../database/knapsack-kcf/KNApSAck" + page + ".kcf")as f1:
        clist = f1.read().split()
        Cnlist.append(clist[1])
print(Cnlist)
# Out:
# ['C00000001', 'C00001119', 'C00002144', 'C00003163', 'C00004172', 'C00005175', 'C00006180', 'C00007188', 'C00008214', 'C00009218', 'C00010225', 'C00011238', 'C00012247', 'C00013252', 'C00014261', 'C00015266', 'C00016267', 'C00017271', 'C00018274', 'C00019276', 'C00020285', 'C00021288', 'C00022289', 'C00023292', 'C00024299', 'C00025305', 'C00026310', 'C00027314', 'C00028321', 'C00029327', 'C00030330', 'C00031343', 'C00032344', 'C00033345', 'C00034347', 'C00035347', 'C00036350', 'C00037352', 'C00038354', 'C00039356', 'C00040358', 'C00041361', 'C00042362', 'C00043363', 'C00044366', 'C00045369', 'C00046369', 'C00047370', 'C00048371', 'C00049371', 'C00050371']

# %%
f.mol_list = []
counter = 0
nCnumber = []
for z, i in enumerate(Cnumber):
    num = int(i[1:])
    for p, k in enumerate(Cnlist[1:]):
        k2 = int(k[1:])
        if k2 > num:
            k3 = str(p+1)
            with open("../../../database/knapsack-kcf/KNApSAck" + k3 + ".kcf")as f2:
                Clist = f2.read().split("///\n")
                try:
                    for C in Clist:
                        if i == C.split()[1]:
                            molblock = kcfco.kcf_to_molblock(C)
                            # print("OK", i)
                            # print(molblock[1])
                            mol = Chem.MolFromMolBlock(molblock[1])
                            if mol is None:
                                print("None", i, z, k3)
                                if "#+" in C or "#-" in C:
                                    print("Charge in\n")
                                counter += 1
                                break
                            rdDepictor.Compute2DCoords(mol)
                            f.mol_list.append(mol)
                            nCnumber.append(i)
                            if "#+" in C or "#-" in C:
                                print(i, z, k3, "Charge in\n")
                            break
                except IndexError:
                    counter += 1
                    print("DAME", i, z)
            break
print(counter)
# Out:
# 0

# %%
mcs = rdFMCS.FindMCS(f.mol_list, matchValences=True, completeRingsOnly=True)
mcs_smarts = mcs.smartsString
mcs_mol = Chem.MolFromSmarts(mcs_smarts)
match_list = []
for m in f.mol_list:
    match_atoms = m.GetSubstructMatch(mcs_mol)
    match_list.append(match_atoms)
img = Draw.MolsToGridImage(f.mol_list, highlightAtomLists=match_list, legends=Cnumber, subImgSize=(400, 400))
img.save(f.genus + "/testtri.png")

# %% [markdown]
# 化合物は9個しか拾えなかったけどこのトリプレットは21個あった。
# トリプレットに注目するのはアリかもしれないけどダブルカウント、トリプレカウントがあることに注意したい。

# %% [markdown]
# 5/9がタンパク質のジスルフィド結合だった
# 残りはよくわかんないの

# %%
Cnumber2 = f.get_Cnlist_from_label2("N-N-N")

# %%
print(Cnumber2)
# Out:
# ['C00017800', 'C00017801', 'C00018404', 'C00018697']

# %%
f.mol_list = []
counter = 0
nCnumber = []
for z, i in enumerate(Cnumber2):
    num = int(i[1:])
    for p, k in enumerate(Cnlist[1:]):
        k2 = int(k[1:])
        if k2 > num:
            k3 = str(p+1)
            with open("../../../database/knapsack-kcf/KNApSAck" + k3 + ".kcf")as f2:
                Clist = f2.read().split("///\n")
                try:
                    for C in Clist:
                        if i == C.split()[1]:
                            molblock = kcfco.kcf_to_molblock(C)
                            # print("OK", i)
                            # print(molblock[1])
                            mol = Chem.MolFromMolBlock(molblock[1])
                            if mol is None:
                                print("None", i, z, k3)
                                if "#+" in C or "#-" in C:
                                    print("Charge in\n")
                                counter += 1
                                break
                            rdDepictor.Compute2DCoords(mol)
                            f.mol_list.append(mol)
                            nCnumber.append(i)
                            if "#+" in C or "#-" in C:
                                print(i, z, k3, "Charge in\n")
                            break
                except IndexError:
                    counter += 1
                    print("DAME", i, z)
            break
print(counter)
# Out:
# 0

# %%
mcs = rdFMCS.FindMCS(f.mol_list, matchValences=True, completeRingsOnly=True)
mcs_smarts = mcs.smartsString
mcs_mol = Chem.MolFromSmarts(mcs_smarts)
match_list = []
for m in f.mol_list:
    match_atoms = m.GetSubstructMatch(mcs_mol)
    match_list.append(match_atoms)
img = Draw.MolsToGridImage(f.mol_list, highlightAtomLists=match_list, legends=Cnumber, subImgSize=(400, 400))
img.save(f.genus + "/testtri2.png")
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-23-026fa920d6cb> in <module>()
#       4 match_list = []
#       5 for m in f.mol_list:
# ----> 6     match_atoms = m.GetSubstructMatch(mcs_mol)
#       7     match_list.append(match_atoms)
#       8 img = Draw.MolsToGridImage(f.mol_list, highlightAtomLists=match_list, legends=Cnumber, subImgSize=(400, 400))
#
# ArgumentError: Python argument types in
#     Mol.GetSubstructMatch(Mol, NoneType)
# did not match C++ signature:
#     GetSubstructMatch(RDKit::ROMol self, RDKit::ROMol query, bool useChirality=False, bool useQueryQueryMatches=False)

# %%
print(f.mol_list)
# Out:
# [<rdkit.Chem.rdchem.Mol object at 0x10f83b118>, <rdkit.Chem.rdchem.Mol object at 0x10f83b320>, <rdkit.Chem.rdchem.Mol object at 0x10f83b388>, <rdkit.Chem.rdchem.Mol object at 0x10f69af50>]

# %%
img = Draw.MolsToGridImage(f.mol_list, legends=Cnumber, subImgSize=(400, 400))
img.save(f.genus + "/testtri2.png")

# %% [markdown]
# mcsが存在しないため怒られた。
# たいして面白い分子じゃなかった。

# %%
bond = []
with open("Streptomyces/kcfscount.txt", "r")as fi:
    if len(bonbon.split("\t")[2].split("-")[0]) == 1:
        print(bonbon)
# Out:
# S00000003B	BOND	C-C	47500
# S00000007B	BOND	C-O	20375
# S00000017B	BOND	C-N	8549
# S00000217B	BOND	C-S	532
# S00000346B	BOND	O-P	265
# S00000472B	BOND	C-X	175
# S00000589B	BOND	N-O	130
# S00000609B	BOND	O-S	124
# S00000914B	BOND	N-N	70
# S00001749B	BOND	O-Z	23
# S00001790B	BOND	C-P	22
# S00002593B	BOND	S-S	11
# S00002744B	BOND	N-P	10
# S00003543B	BOND	N-S	6
# S00004938B	BOND	N-Z	3
# S00005793B	BOND	C-Z	2
# S00005829B	BOND	O-O	2
# S00005834B	BOND	P-S	2

# %%
Cnumber3 = f.get_Cnlist_from_label2("O-Z-O")
print(Cnumber3)
# Out:
# ['C00016132', 'C00018072', 'C00018108', 'C00018186', 'C00018187', 'C00018794']

# %%
f.mol_list = []
counter = 0
nCnumber = []
for z, i in enumerate(Cnumber3):
    num = int(i[1:])
    for p, k in enumerate(Cnlist[1:]):
        k2 = int(k[1:])
        if k2 > num:
            k3 = str(p+1)
            with open("../../../database/knapsack-kcf/KNApSAck" + k3 + ".kcf")as f2:
                Clist = f2.read().split("///\n")
                try:
                    for C in Clist:
                        if i == C.split()[1]:
                            molblock = kcfco.kcf_to_molblock(C)
                            # print("OK", i)
                            # print(molblock[1])
                            mol = Chem.MolFromMolBlock(molblock[1])
                            if mol is None:
                                print("None", i, z, k3)
                                if "#+" in C or "#-" in C:
                                    print("Charge in\n")
                                counter += 1
                                break
                            rdDepictor.Compute2DCoords(mol)
                            f.mol_list.append(mol)
                            nCnumber.append(i)
                            if "#+" in C or "#-" in C:
                                print(i, z, k3, "Charge in\n")
                            break
                except IndexError:
                    counter += 1
                    print("DAME", i, z)
            break
print(counter)
# Out:
# None C00016132 0 16
# Charge in
#
# None C00018072 1 18
# Charge in
#
# None C00018108 2 18
# Charge in
#
# None C00018186 3 18
# Charge in
#
# None C00018187 4 18
# Charge in
#
# 5

# %% [markdown]
# 5/6が金属錯体だった。

# %%
def get_label_test(label):
    import re
    Cnlist = []
    label_list = re.split("[-()]", label)
    sep_list = re.split("[a-zA-Z][0-9]?[a-z]?", label)
    query = ""
    for i in range(label_list.count("")):
        label_list.remove("")
    for i in range(len(label_list)):
        label_list[i] += "[0-9]?[a-z]?"
    for l1, l2 in zip(sep_list, label_list):
        query += l1 + l2
    query = re.sub("\(", "[(]", query)
    query = re.sub("\)", "[)]", query)
    for page in ["1-9", "10-19", "20-29", "30-39", "40-49", "50-59"]:
        with open("../../../database/kcfs/KNApSAck" + page + ".kcfs")as f:
            file = f.read()
            molecule = file.split("///\n")
            for mole in molecule:
                if re.search(query, mole) is not None:
                    Cn = mole.split("\n")[0].split()[1]
                    Cnlist.append(Cn)
    return Cnlist

# %%
test = get_label_test("C(C)-C(C)-C(C-C-C-C-C-C)-C-C-C-C-C-C-C-C-C")

# %%
print(test)
# Out:
# ['C00015228', 'C00015229', 'C00015660', 'C00015661', 'C00015730', 'C00015731', 'C00015732', 'C00016476', 'C00016751', 'C00016938', 'C00017103', 'C00017152', 'C00017237', 'C00017543', 'C00017544', 'C00017573', 'C00017671', 'C00017726', 'C00017790', 'C00017791', 'C00017792', 'C00017865', 'C00018127', 'C00023963', 'C00023964', 'C00024681', 'C00024682', 'C00024683', 'C00024684', 'C00024685', 'C00024753', 'C00026595', 'C00026596', 'C00027661', 'C00027732', 'C00027760', 'C00027763', 'C00027893', 'C00027894', 'C00028349', 'C00028350', 'C00028707', 'C00029133', 'C00029261']

# %%
print(len(test))
# Out:
# 44

# %%
lis = f.get_Cnlist_from_label2("C(C)-C(C)-C(C-C-C-C-C-C)-C-C-C-C-C-C-C-C-C")

# %%
print(lis)
# Out:
# ['C00015228', 'C00015229', 'C00016476', 'C00016751', 'C00016938', 'C00017103', 'C00017237', 'C00017544', 'C00017573', 'C00017671', 'C00017726', 'C00017791', 'C00017792', 'C00018127', 'C00024753', 'C00026595', 'C00026596', 'C00028349', 'C00028350', 'C00028707']

# %%
sabun = []
for i in test:
    if i not in lis:
        print(i)
        sabun.append(i)
# Out:
# C00015660
# C00015661
# C00015730
# C00015731
# C00015732
# C00017152
# C00017543
# C00017790
# C00017865
# C00023963
# C00023964
# C00024681
# C00024682
# C00024683
# C00024684
# C00024685
# C00027661
# C00027732
# C00027760
# C00027763
# C00027893
# C00027894
# C00029133
# C00029261

# %%
print(sabun)
# Out:
# ['C00015660', 'C00015661', 'C00015730', 'C00015731', 'C00015732', 'C00017152', 'C00017543', 'C00017790', 'C00017865', 'C00023963', 'C00023964', 'C00024681', 'C00024682', 'C00024683', 'C00024684', 'C00024685', 'C00027661', 'C00027732', 'C00027760', 'C00027763', 'C00027893', 'C00027894', 'C00029133', 'C00029261']

# %%
print(len(sabun))
# Out:
# 24

# %%
f.mol_list = []
counter = 0
nCnumber = []
for z, i in enumerate(sabun):
    num = int(i[1:])
    for p, k in enumerate(Cnlist[1:]):
        k2 = int(k[1:])
        if k2 > num:
            k3 = str(p+1)
            with open("../../../database/knapsack-kcf/KNApSAck" + k3 + ".kcf")as f2:
                Clist = f2.read().split("///\n")
                try:
                    for C in Clist:
                        if i == C.split()[1]:
                            molblock = kcfco.kcf_to_molblock(C)
                            # print("OK", i)
                            # print(molblock[1])
                            mol = Chem.MolFromMolBlock(molblock[1])
                            if mol is None:
                                print("None", i, z, k3)
                                if "#+" in C or "#-" in C:
                                    print("Charge in\n")
                                counter += 1
                                break
                            rdDepictor.Compute2DCoords(mol)
                            f.mol_list.append(mol)
                            nCnumber.append(i)
                            if "#+" in C or "#-" in C:
                                print(i, z, k3, "Charge in\n")
                            break
                except IndexError:
                    counter += 1
                    print("DAME", i, z)
            break
print(counter)
# Out:
# 0

# %%
img = Draw.MolsToGridImage(f.mol_list, legends=sabun, subImgSize=(400, 400))
img.save(f.genus + "/testsabun.png")

# %%
import time
genuses = []
for num in sabun:
    genuses.append(f.get_genuses(num))
    time.sleep(0.5)

# %%
print(genuses)
# Out:
# [['Micromonospora sp. L-31-CLCO-002'], ['Micromonospora sp. L-31-CLCO-002'], ['Lechevalieria aerocolonigenes ATCC 39243'], ['Lechevalieria aerocolonigenes ATCC 39243'], ['Lechevalieria aerocolonigenes ATCC 39243'], ['Lechevalieria aerocolonigenes ATCC 39243'], ['Nocardia dassonvillei C-71425'], ['Nocardiopsis sp. K-290'], ['Nocardia aerocolonigens C-38383-RK-2', 'Lechevalieria aerocolonigenes C-38383'], ['Arcyria denudata', 'Arcyria nutans', 'Tubifera casparyi', 'Metatrichia vesparium'], ['Arcyria denudata', 'Arcyria ferruginea', 'Arcyria nutans', 'Tubifera casparyi', 'Metatrichia vesparium'], [], ['Actinomadura melliaura sp.nov.(SCC 1655)'], ['Actinomadura melliaura sp.'], ['Actinomadura melliaura sp.'], ['Actinomadura melliaura sp.'], ['Galanthus plicatus spp.byzantinus', 'Hippeastrum equestre', 'Leucojum vernum', 'Pancratium canariense', 'Pancratium sickenbergeri'], ['Coriocella nigra'], ['Eudistoma toealensis', 'Coriocella nigra'], [], ['Arcyria denudata', 'Arcyria nutans', 'Lycogala epidendrum'], ['Dictydiaethalium plumbeum'], ['Tolypothrix tjipanasensis DB-1-1A'], ['Actinomadura sp. strain 007']]

# %%
len(genuses)
# Out:
# 24

# %%
import os
print(os.getpid())
# Out:
# 1880

# %%
for genus in genuses:
    print(genus)
# Out:
# ['Micromonospora sp. L-31-CLCO-002']
# ['Micromonospora sp. L-31-CLCO-002']
# ['Lechevalieria aerocolonigenes ATCC 39243']
# ['Lechevalieria aerocolonigenes ATCC 39243']
# ['Lechevalieria aerocolonigenes ATCC 39243']
# ['Lechevalieria aerocolonigenes ATCC 39243']
# ['Nocardia dassonvillei C-71425']
# ['Nocardiopsis sp. K-290']
# ['Nocardia aerocolonigens C-38383-RK-2', 'Lechevalieria aerocolonigenes C-38383']
# ['Arcyria denudata', 'Arcyria nutans', 'Tubifera casparyi', 'Metatrichia vesparium']
# ['Arcyria denudata', 'Arcyria ferruginea', 'Arcyria nutans', 'Tubifera casparyi', 'Metatrichia vesparium']
# []
# ['Actinomadura melliaura sp.nov.(SCC 1655)']
# ['Actinomadura melliaura sp.']
# ['Actinomadura melliaura sp.']
# ['Actinomadura melliaura sp.']
# ['Galanthus plicatus spp.byzantinus', 'Hippeastrum equestre', 'Leucojum vernum', 'Pancratium canariense', 'Pancratium sickenbergeri']
# ['Coriocella nigra']
# ['Eudistoma toealensis', 'Coriocella nigra']
# []
# ['Arcyria denudata', 'Arcyria nutans', 'Lycogala epidendrum']
# ['Dictydiaethalium plumbeum']
# ['Tolypothrix tjipanasensis DB-1-1A']
# ['Actinomadura sp. strain 007']

# %%
for i, genus in enumerate(genuses):
    if genus == []:
        print(sabun[i])
# Out:
# C00024681
# C00027763

# %% [markdown]
# 手持ちの全部のkcf-sから抜き出してみた。
# 2個ほどページが存在しなかった。

# %% [markdown]
# この単位はストレプトマイセス固有だったのか怪しいが、一つの属で20こ持っているのはこれなので固有感もある。
